# %%
import pandas as pd
import numpy as np
import re
from ast import literal_eval

# %%
def fixArrays(x):
    start = x.find("[") + len("[")
    end = x.find("]")
    substring = x[start:end].replace("'", "")
    return substring.split(",")

def entitiesMatch(x, y):
    count = 0
    for item1 in x:
        for item2 in y:
            if(item1.strip() == item2.strip()):
                count += 1
                break
    return count

def duplicateElimination(l):
    res = []
    [res.append(x) for x in l if x not in res]
    return res

# %%
data = pd.read_csv("datasets/questions_answers_combined.csv", lineterminator='\n', encoding="ISO-8859-1")
data['title_entities'] = data.apply(lambda x: literal_eval(x['title_entities']), axis = 1)
data['question_body_entities'] = data.apply(lambda x: literal_eval(x['question_body_entities']), axis = 1)
data['answer_body_entities'] = data.apply(lambda x: literal_eval(x['answer_body_entities']), axis = 1)
data.head()
# Out:
#    Unnamed: 0  question_user_id  accepted_answer_id  answer_count  \
# 0           0            2490.0               22587             6
# 1           1            2490.0               22587             6
# 2           2            2490.0               22587             6
# 3           3            2490.0               22587             6
# 4           4            2490.0               22587             6
#
#    question_score creation_date  question_id  \
# 0              11    2008-08-22        22528
# 1              11    2008-08-22        22528
# 2              11    2008-08-22        22528
# 3              11    2008-08-22        22528
# 4              11    2008-08-22        22528
#
#                                                 link                title  \
# 0  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
# 1  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
# 2  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
# 3  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
# 4  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
#
#                                        question_body  ...  \
# 0  <p>I would like to have a reference for the pr...  ...
# 1  <p>I would like to have a reference for the pr...  ...
# 2  <p>I would like to have a reference for the pr...  ...
# 3  <p>I would like to have a reference for the pr...  ...
# 4  <p>I would like to have a reference for the pr...  ...
#
#                               question_body_entities answer_id is_accepted  \
# 0  [PHP, one, A Simple Example: Certain pages on,...     22594       False
# 1  [PHP, one, A Simple Example: Certain pages on,...     22587        True
# 2  [PHP, one, A Simple Example: Certain pages on,...     22578       False
# 3  [PHP, one, A Simple Example: Certain pages on,...     22551       False
# 4  [PHP, one, A Simple Example: Certain pages on,...     22537       False
#
#                                          answer_body answer_user_id  \
# 0  <p>While the question touches on a couple of v...         2494.0
# 1  <p>These are not really opposite choices. You ...          341.0
# 2  <p>Whether you do it in classes or in a more p...         1344.0
# 3  <p>I've learned never to use <code>include</co...         1968.0
# 4  <p>Can you be a bit more specific? For the exa...         1830.0
#
#   reputation  answer_score                                    answer_body_doc  \
# 0    17497.0             5  While the question touches on a couple of very...
# 1    17787.0            13  These are not really opposite choices. You wil...
# 2    21216.0             0  Whether you do it in classes or in a more proc...
# 3   480242.0             1  I've learned never to use include in PHP excep...
# 4    10583.0             0  Can you be a bit more specific? For the exampl...
#
#                                    answer_body_token  \
# 0  ['While', 'the', 'question', 'touches', 'on', ...
# 1  ['These', 'are', 'not', 'really', 'opposite', ...
# 2  ['Whether', 'you', 'do', 'it', 'in', 'classes'...
# 3  ['I', "'ve", 'learned', 'never', 'to', 'use', ...
# 4  ['Can', 'you', 'be', 'a', 'bit', 'more', 'spec...
#
#                                 answer_body_entities
# 0                   [User, second, Konrad, OOP, PHP]
# 1                              [PHP3, eCommerce PHP]
# 2  [three, one, Session, Session, 0, 1, 2, PHPSES...
# 3                                         [PHP, one]
# 4                                       [1, 2, User]
#
# [5 rows x 25 columns]

# %%
data['code_snippet_count'] = data.apply(lambda x: x['answer_body'].count('<pre><code>'), axis = 1)
data['link_count'] = data.apply(lambda x: x['answer_body'].count('<a href='), axis = 1)

data.head()
# Out:
#    Unnamed: 0  question_user_id  accepted_answer_id  answer_count  \
# 0           0            2490.0               22587             6
# 1           1            2490.0               22587             6
# 2           2            2490.0               22587             6
# 3           3            2490.0               22587             6
# 4           4            2490.0               22587             6
#
#    question_score creation_date  question_id  \
# 0              11    2008-08-22        22528
# 1              11    2008-08-22        22528
# 2              11    2008-08-22        22528
# 3              11    2008-08-22        22528
# 4              11    2008-08-22        22528
#
#                                                 link                title  \
# 0  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
# 1  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
# 2  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
# 3  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
# 4  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
#
#                                        question_body  ... is_accepted  \
# 0  <p>I would like to have a reference for the pr...  ...       False
# 1  <p>I would like to have a reference for the pr...  ...        True
# 2  <p>I would like to have a reference for the pr...  ...       False
# 3  <p>I would like to have a reference for the pr...  ...       False
# 4  <p>I would like to have a reference for the pr...  ...       False
#
#                                          answer_body answer_user_id  \
# 0  <p>While the question touches on a couple of v...         2494.0
# 1  <p>These are not really opposite choices. You ...          341.0
# 2  <p>Whether you do it in classes or in a more p...         1344.0
# 3  <p>I've learned never to use <code>include</co...         1968.0
# 4  <p>Can you be a bit more specific? For the exa...         1830.0
#
#   reputation answer_score                                    answer_body_doc  \
# 0    17497.0            5  While the question touches on a couple of very...
# 1    17787.0           13  These are not really opposite choices. You wil...
# 2    21216.0            0  Whether you do it in classes or in a more proc...
# 3   480242.0            1  I've learned never to use include in PHP excep...
# 4    10583.0            0  Can you be a bit more specific? For the exampl...
#
#                                    answer_body_token  \
# 0  ['While', 'the', 'question', 'touches', 'on', ...
# 1  ['These', 'are', 'not', 'really', 'opposite', ...
# 2  ['Whether', 'you', 'do', 'it', 'in', 'classes'...
# 3  ['I', "'ve", 'learned', 'never', 'to', 'use', ...
# 4  ['Can', 'you', 'be', 'a', 'bit', 'more', 'spec...
#
#                                 answer_body_entities code_snippet_count  \
# 0                   [User, second, Konrad, OOP, PHP]                  0
# 1                              [PHP3, eCommerce PHP]                  0
# 2  [three, one, Session, Session, 0, 1, 2, PHPSES...                  1
# 3                                         [PHP, one]                  0
# 4                                       [1, 2, User]                  0
#
#    link_count
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0
#
# [5 rows x 27 columns]

# %%
data['question_entities'] = data.apply(lambda x: x['title_entities'] + x['question_body_entities'], axis = 1)
data['question_entities'] = data.apply(lambda x: duplicateElimination(x['question_entities']), axis = 1)
data['answer_body_entities'] = data.apply(lambda x: duplicateElimination(x['answer_body_entities']), axis = 1)

data['entities_matches'] = data.apply(lambda x: entitiesMatch(x['question_entities'], x['answer_body_entities']), axis = 1)
data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-207-7af828b4c9a9> in <module>
#       1 data['question_entities'] = data.apply(lambda x: x['title_entities'] + x['question_body_entities'], axis = 1)
#       2 data['question_entities'] = data.apply(lambda x: duplicateElimination(x['question_entities']), axis = 1)
# ----> 3 data['answer_body_entities'] = data.apply(lambda x: duplicateElimination(literal_eval(x['answer_body_entities'])), axis = 1)
#       4
#       5 data['entities_matches'] = data.apply(lambda x: entitiesMatch(x['question_entities'], x['answer_body_entities']), axis = 1)
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# --> 276         results, res_index = self.apply_series_generator()
#     277
#     278         # wrap results
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     288             for i, v in enumerate(series_gen):
#     289                 # ignore SettingWithCopy here in case the user mutates
# --> 290                 results[i] = self.f(v)
#     291                 if isinstance(results[i], ABCSeries):
#     292                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-207-7af828b4c9a9> in <lambda>(x)
#       1 data['question_entities'] = data.apply(lambda x: x['title_entities'] + x['question_body_entities'], axis = 1)
#       2 data['question_entities'] = data.apply(lambda x: duplicateElimination(x['question_entities']), axis = 1)
# ----> 3 data['answer_body_entities'] = data.apply(lambda x: duplicateElimination(literal_eval(x['answer_body_entities'])), axis = 1)
#       4
#       5 data['entities_matches'] = data.apply(lambda x: entitiesMatch(x['question_entities'], x['answer_body_entities']), axis = 1)
#
# /opt/tljh/user/lib/python3.7/ast.py in literal_eval(node_or_string)
#      89                     return left - right
#      90         return _convert_signed_num(node)
# ---> 91     return _convert(node_or_string)
#      92
#      93
#
# /opt/tljh/user/lib/python3.7/ast.py in _convert(node)
#      88                 else:
#      89                     return left - right
# ---> 90         return _convert_signed_num(node)
#      91     return _convert(node_or_string)
#      92
#
# /opt/tljh/user/lib/python3.7/ast.py in _convert_signed_num(node)
#      61             else:
#      62                 return - operand
# ---> 63         return _convert_num(node)
#      64     def _convert(node):
#      65         if isinstance(node, Constant):
#
# /opt/tljh/user/lib/python3.7/ast.py in _convert_num(node)
#      53         elif isinstance(node, Num):
#      54             return node.n
# ---> 55         raise ValueError('malformed node or string: ' + repr(node))
#      56     def _convert_signed_num(node):
#      57         if isinstance(node, UnaryOp) and isinstance(node.op, (UAdd, USub)):
#
# ValueError: malformed node or string: ['User', 'second', 'Konrad', 'OOP', 'PHP']

# %%
data.to_csv('datasets/code_link_features.csv')

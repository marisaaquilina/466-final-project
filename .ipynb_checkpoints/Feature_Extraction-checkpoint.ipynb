# %%
import pandas as pd
import numpy as np
import re
from ast import literal_eval
from bs4 import BeautifulSoup, Tag

# %%
def getParagraphLength(data):
    soup = BeautifulSoup(data['answer_body'])
    for tag in soup.find_all('code'):
        tag.replaceWith('')

    return len(soup.get_text())

# %%
def fixArrays(x):
    start = x.find("[") + len("[")
    end = x.find("]")
    substring = x[start:end].replace("'", "")
    return substring.split(",")

def entitiesMatch(x, y):
    count = 0
    for item1 in x:
        for item2 in y:
            if(item1.strip() == item2.strip()):
                count += 1
                break
    return count

def duplicateElimination(l):
    res = []
    [res.append(x) for x in l if x not in res]
    return res

# %%
data = pd.read_csv("datasets/questions_answers_combined.csv", lineterminator='\n', encoding="ISO-8859-1")
data['title_entities'] = data.apply(lambda x: literal_eval(x['title_entities']), axis = 1)
data['question_body_entities'] = data.apply(lambda x: literal_eval(x['question_body_entities']), axis = 1)
data['answer_body_entities'] = data.apply(lambda x: literal_eval(x['answer_body_entities']), axis = 1)
data.head()
# Out:
#    question_user_id  accepted_answer_id  answer_count  question_score  \
# 0            2490.0               22587             6              11
# 1            2490.0               22587             6              11
# 2            2490.0               22587             6              11
# 3            2490.0               22587             6              11
# 4            2490.0               22587             6              11
#
#   creation_date  question_id  \
# 0       8/22/08        22528
# 1       8/22/08        22528
# 2       8/22/08        22528
# 3       8/22/08        22528
# 4       8/22/08        22528
#
#                                                 link                title  \
# 0  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
# 1  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
# 2  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
# 3  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
# 4  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
#
#                                        question_body            title_doc  \
# 0  <p>I would like to have a reference for the pr...  PHP includes vs OOP
# 1  <p>I would like to have a reference for the pr...  PHP includes vs OOP
# 2  <p>I would like to have a reference for the pr...  PHP includes vs OOP
# 3  <p>I would like to have a reference for the pr...  PHP includes vs OOP
# 4  <p>I would like to have a reference for the pr...  PHP includes vs OOP
#
#    ...                             question_body_entities answer_id  \
# 0  ...  [PHP, one, A Simple Example: Certain pages on,...     22594
# 1  ...  [PHP, one, A Simple Example: Certain pages on,...     22587
# 2  ...  [PHP, one, A Simple Example: Certain pages on,...     22578
# 3  ...  [PHP, one, A Simple Example: Certain pages on,...     22551
# 4  ...  [PHP, one, A Simple Example: Certain pages on,...     22537
#
#   is_accepted                                        answer_body  \
# 0       False  <p>While the question touches on a couple of v...
# 1        True  <p>These are not really opposite choices. You ...
# 2       False  <p>Whether you do it in classes or in a more p...
# 3       False  <p>I've learned never to use <code>include</co...
# 4       False  <p>Can you be a bit more specific? For the exa...
#
#   answer_user_id  reputation  answer_score  \
# 0         2494.0     17497.0             5
# 1          341.0     17787.0            13
# 2         1344.0     21216.0             0
# 3         1968.0    480242.0             1
# 4         1830.0     10583.0             0
#
#                                      answer_body_doc  \
# 0  While the question touches on a couple of very...
# 1  These are not really opposite choices. You wil...
# 2  Whether you do it in classes or in a more proc...
# 3  I've learned never to use include in PHP excep...
# 4  Can you be a bit more specific? For the exampl...
#
#                                    answer_body_token  \
# 0  ['While', 'the', 'question', 'touches', 'on', ...
# 1  ['These', 'are', 'not', 'really', 'opposite', ...
# 2  ['Whether', 'you', 'do', 'it', 'in', 'classes'...
# 3  ['I', "'ve", 'learned', 'never', 'to', 'use', ...
# 4  ['Can', 'you', 'be', 'a', 'bit', 'more', 'spec...
#
#                                 answer_body_entities
# 0                   [User, second, Konrad, OOP, PHP]
# 1                              [PHP3, eCommerce PHP]
# 2  [three, one, Session, Session, 0, 1, 2, PHPSES...
# 3                                         [PHP, one]
# 4                                       [1, 2, User]
#
# [5 rows x 24 columns]

# %%
data['code_snippet_count'] = data.apply(lambda x: x['answer_body'].count('<pre><code>'), axis = 1)
data['link_count'] = data.apply(lambda x: x['answer_body'].count('<a href='), axis = 1)

data.head()
# Out:
#    question_user_id  accepted_answer_id  answer_count  question_score  \
# 0            2490.0               22587             6              11
# 1            2490.0               22587             6              11
# 2            2490.0               22587             6              11
# 3            2490.0               22587             6              11
# 4            2490.0               22587             6              11
#
#   creation_date  question_id  \
# 0       8/22/08        22528
# 1       8/22/08        22528
# 2       8/22/08        22528
# 3       8/22/08        22528
# 4       8/22/08        22528
#
#                                                 link                title  \
# 0  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
# 1  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
# 2  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
# 3  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
# 4  https://stackoverflow.com/questions/22528/php-...  PHP includes vs OOP
#
#                                        question_body            title_doc  \
# 0  <p>I would like to have a reference for the pr...  PHP includes vs OOP
# 1  <p>I would like to have a reference for the pr...  PHP includes vs OOP
# 2  <p>I would like to have a reference for the pr...  PHP includes vs OOP
# 3  <p>I would like to have a reference for the pr...  PHP includes vs OOP
# 4  <p>I would like to have a reference for the pr...  PHP includes vs OOP
#
#    ... is_accepted                                        answer_body  \
# 0  ...       False  <p>While the question touches on a couple of v...
# 1  ...        True  <p>These are not really opposite choices. You ...
# 2  ...       False  <p>Whether you do it in classes or in a more p...
# 3  ...       False  <p>I've learned never to use <code>include</co...
# 4  ...       False  <p>Can you be a bit more specific? For the exa...
#
#   answer_user_id reputation answer_score  \
# 0         2494.0    17497.0            5
# 1          341.0    17787.0           13
# 2         1344.0    21216.0            0
# 3         1968.0   480242.0            1
# 4         1830.0    10583.0            0
#
#                                      answer_body_doc  \
# 0  While the question touches on a couple of very...
# 1  These are not really opposite choices. You wil...
# 2  Whether you do it in classes or in a more proc...
# 3  I've learned never to use include in PHP excep...
# 4  Can you be a bit more specific? For the exampl...
#
#                                    answer_body_token  \
# 0  ['While', 'the', 'question', 'touches', 'on', ...
# 1  ['These', 'are', 'not', 'really', 'opposite', ...
# 2  ['Whether', 'you', 'do', 'it', 'in', 'classes'...
# 3  ['I', "'ve", 'learned', 'never', 'to', 'use', ...
# 4  ['Can', 'you', 'be', 'a', 'bit', 'more', 'spec...
#
#                                 answer_body_entities  code_snippet_count  \
# 0                   [User, second, Konrad, OOP, PHP]                   0
# 1                              [PHP3, eCommerce PHP]                   0
# 2  [three, one, Session, Session, 0, 1, 2, PHPSES...                   1
# 3                                         [PHP, one]                   0
# 4                                       [1, 2, User]                   0
#
#    link_count
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0
#
# [5 rows x 26 columns]

# %%
data['question_entities'] = data.apply(lambda x: x['title_entities'] + x['question_body_entities'], axis = 1)
data['question_entities'] = data.apply(lambda x: duplicateElimination(x['question_entities']), axis = 1)
data['answer_body_entities'] = data.apply(lambda x: duplicateElimination(x['answer_body_entities']), axis = 1)

data['entities_matches'] = data.apply(lambda x: entitiesMatch(x['question_entities'], x['answer_body_entities']), axis = 1)

data['reply_by_author'] = data.apply(lambda x: True if x['answer_user_id'] == \
                                         x['question_user_id'] else False, axis = 1)

data['a_score_rel_q_score'] = data.apply(lambda x: x['answer_score'] - x['question_score'], \
                                     axis = 1)

data['len_answer_text'] = data.apply(lambda x: getParagraphLength(x), \
                                     axis = 1)

data = data[['question_id', 'answer_id', 'a_score_rel_q_score', 'answer_score', 'entities_matches', \
           'reputation', 'reply_by_author', 'len_answer_text', 'is_accepted', 'code_snippet_count', 'link_count']]
data.head()
# Out:
#    question_id  answer_id  a_score_rel_q_score  answer_score  \
# 0        22528      22594                   -6             5
# 1        22528      22587                    2            13
# 2        22528      22578                  -11             0
# 3        22528      22551                  -10             1
# 4        22528      22537                  -11             0
#
#    entities_matches  reputation  reply_by_author  len_answer_text  \
# 0                 1     17497.0            False              628
# 1                 0     17787.0            False              699
# 2                 1     21216.0            False              338
# 3                 2    480242.0            False              422
# 4                 0     10583.0            False              318
#
#    is_accepted  code_snippet_count  link_count
# 0        False                   0           0
# 1         True                   0           1
# 2        False                   1           0
# 3        False                   0           0
# 4        False                   0           0

# %%
data.to_csv('datasets/features.csv', index=False)
